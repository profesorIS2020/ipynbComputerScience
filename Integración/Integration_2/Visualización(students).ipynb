# %% [markdown]
# ##### Actividad para la próxima clase
# Cada estudiante  debe hacer un ejercicio aplicando el patrón dado en clases y una función de la biblioteca statistics de Python, graficando su contenido y agregrando la media y la moda al gráfico.

# %%
#%pip install matplotlib
# Librería statistics

# Medidas de tendencia central
def calcular_media(lista):
    return statistics.mean(lista)

def calcular_mediana(lista):
    return statistics.median(lista)


# Medidas de dispersión
def calcular_desviacion_estandar_muestra(lista):
    return statistics.stdev(lista)
def calcular_moda(lista):
    return statistics.mode(lista)

# Medidas de correlación
def calcular_correlacion(lista1, lista2):
    return statistics.correlation(lista1, lista2)
# Medidas de regresión
def calcular_regresion(lista1, lista2):
    return statistics.linear_regression(lista1, lista2)


def main():
    # Generar una lista de 1000 números aleatorios entre 1 y 100
    lista = [random.randint(1, 100) for _ in range(1000)]
    # Calcular la mediana  
    mediana = calcular_mediana(lista)
    # Imprimir la mediana
    print(f"La mediana de la lista es: {mediana}")
    # Graficar la lista
    plt.hist(lista, bins=10, edgecolor='black')
    plt.title('Histograma de la lista') 
    plt.xlabel('Valores')
    plt.ylabel('Frecuencia')
    plt.axvline(mediana, color='r', linestyle='dashed', linewidth=1)
    plt.axvline(mediana, color='r', linestyle='dashed', linewidth=1)
    plt.text(mediana+1, 50, f'Mediana: {mediana}', color='red')
    plt.show()
    # Graficar la mediana
    plt.axvline(mediana, color='r', linestyle='dashed', linewidth=1)
    plt.text(mediana+1, 50, f'Mediana: {mediana}', color='red')
    plt.show()
    # Calcular la media
    media = calcular_media(lista)
    # Imprimir la media
    print(f"La media de la lista es: {media}")
    # Graficar la media
    plt.axvline(media, color='g', linestyle='dashed', linewidth=1)
    plt.text(media+1, 50, f'Media: {media}', color='green')
    plt.show()
if __name__ == "__main__":
    import random
    import statistics
    import matplotlib.pyplot as plt
    main()
# Out:
# La mediana de la lista es: 51.0
# La media de la lista es: 50.565

# %%
# %pip install matplotlib
# El método random.uniform(a,b) devuelve un número float decimal aleatorio entre a y b, excluyendo ambos extremos
# Generador de listas por comprensión: [random.uniform(1, 10) for _ in range(10)]
# random.uniform(1, 10) : Genera un número aleatorio entre 1 y 10
# for _ in range(10) : Es un bucle que repite 10 veces. Usas la variable anónima _ cuando no necesitas usar el valor de un contador (es como
# si dijeras al programa: Olvidate de todo, solo repite 10 veces)
# Los corchetes [...] indican que todo el bucle se ejecute en una lista

def create_list():
    # Generar una lista de números aleatorios
    lista_numeros = [random.uniform(1, 10) for _ in range(10)]
    return lista_numeros

def calcular_mediana(lista):
    return statistics.median(lista)

def calcular_stdev(lista):
    return statistics.stdev(lista)

def main():
    lista = create_list()
    # Calcular y mostrar la mediana y desviación típica
    print("Lista de números:", lista)
    print("Mediana:", calcular_mediana(lista))
    print("Desviación Típica:", calcular_stdev(lista))

    # Histograma
    # La función hist() de matplotlib crea un histograma a partir de los datos de la lista
    # figsize especifica el tamaño de la figura
    # bins especifica el número de intervalos en el histograma
    # La función grid() añade una cuadrícula al gráfico
    # La función show() muestra el gráfico
    # La función title() establece el título del gráfico
    plt.figure(figsize=(10, 5))
    plt.hist(lista, bins=10, edgecolor='black')
    plt.title("Histograma de Números")
    plt.xlabel("Valor")
    plt.ylabel("Frecuencia")
    plt.grid(True)
    plt.show()

    # Histogram with mode and median lines
    # La función hist() de matplotlib crea un histograma a partir de los datos de la lista
    # edgecolor='black' añade un borde 
    # alpha=0.7 establece la transparencia del histograma
    # La función axvline() dibuja una línea vertical en la posición de la mediana
    # La función legend() añade una leyenda al gráfico
    # La función grid() añade una cuadrícula al gráfico
    plt.figure(figsize=(10, 5))
    plt.hist(lista, bins=10, edgecolor='black', alpha=0.7)
    plt.axvline(calcular_mediana(lista), color='red', linestyle='-', linewidth=2, label=f'Mediana: {calcular_mediana(lista):.2f}')
    plt.title("Histograma con Mediana")
    plt.xlabel("Valor")
    plt.ylabel("Frecuencia")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Boxplot es una representación gráfica de la distribución de un conjunto de datos
    # que muestra la mediana, los cuartiles y los valores atípicos
    # La función boxplot() de matplotlib crea un boxplot a partir de los datos de la lista
    # La función title() establece el título del gráfico
    # La función ylabel() establece la etiqueta del eje y
    # La función grid() añade una cuadrícula al gráfico
    # La función show() muestra el gráfico
    # La función annotate() añade una anotación al gráfico   

    # Boxplot
    plt.figure(figsize=(6, 4))
    plt.boxplot(lista)
    plt.title("Diagrama de Caja (Boxplot)")
    plt.ylabel("Valor")
    plt.grid(True)
    plt.annotate(f'Mediana: {calcular_mediana(lista):.2f}', xy=(1, calcular_mediana(lista)), xytext=(1.1, calcular_mediana(lista) + 0.5),
                 arrowprops=dict(facecolor='black', arrowstyle='->'), fontsize=10, color='red')
    plt.show()


    # Scatter plot
    plt.figure(figsize=(10, 5))
    plt.plot(lista, marker='o', linestyle='-', alpha=0.7)
    plt.title("Secuencia de Números Aleatorios")
    plt.xlabel("Índice")
    plt.ylabel("Valor")
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    import random
    import statistics
    import matplotlib.pyplot as plt
    main()
# Out:
# Lista de números: [5.27050588284864, 7.521060742031789, 5.57710185599731, 9.672801322844618, 3.494433424664397, 7.4762033609479275, 4.700097637298568, 5.621571847506326, 9.009789874900777, 9.928800629577674]
# Mediana: 6.548887604227127
# Desviación Típica: 2.2224910620390164

# %%
#%pip install matplotlib

# Diccionario por comprensión

def get_names():
    # Generar un diccionario de nombres y edades
    nombres = [
        "Nicolás", "Carlos", "Luis Gabriel", "Alfonso", "José Ignacio", 
        "Emilio Eugenio", "Diana del Carmen", "Pablo", "Daniel", 
        "Maria del Sol", "Jessica Ximena del Pilar", "Rodrigo", "Jorge", 
        "Diana Fernanda", "Luis Fernando", "Javier", "Pedro", "Paloma", 
        "Marcos", "Enrique", "Guiomar", "Daira", "Santiago", "Luis Enrique"
    ]
    return nombres

def get_grades():
    nombres = get_names()
    grades = {name: round(random.uniform(1, 10),2) for name in nombres}
    return grades

def calcular_mediana(lista):
    return statistics.median(lista)

def calcular_stdev(lista):
    return statistics.stdev(lista)

def create_hist(lista):
    # Histograma
    # La función hist() de matplotlib crea un histograma a partir de los datos de la lista
    # figsize especifica el tamaño de la figura
    # bins especifica el número de intervalos en el histograma
    # La función grid() añade una cuadrícula al gráfico
    # La función show() muestra el gráfico
    # La función title() establece el título del gráfico
    plt.figure(figsize=(10, 5))
    plt.hist(lista, bins=10, edgecolor='black')
    plt.title("Histograma de Números")
    plt.xlabel("Valor")
    plt.ylabel("Frecuencia")
    plt.grid(True)
    plt.show()

def create_hist_with_median(lista):
    # Histogram with mode and median lines
    # La función hist() de matplotlib crea un histograma a partir de los datos de la lista
    # edgecolor='black' añade un borde 
    # alpha=0.7 establece la transparencia del histograma
    # La función axvline() dibuja una línea vertical en la posición de la mediana
    # La función legend() añade una leyenda al gráfico
    # La función grid() añade una cuadrícula al gráfico
    plt.figure(figsize=(10, 5))
    plt.hist(lista, bins=10, edgecolor='black', alpha=0.7)
    plt.axvline(calcular_mediana(lista), color='red', linestyle='-', linewidth=2, label=f'Mediana: {calcular_mediana(lista):.2f}')
    plt.title("Histograma con Mediana")
    plt.xlabel("Valor")
    plt.ylabel("Frecuencia")
    plt.legend()
    plt.grid(True)
    plt.show()

def create_boxplot(lista):  
    # Boxplot es una representación gráfica de la distribución de un conjunto de datos
    # que muestra la mediana, los cuartiles y los valores atípicos
    # La función boxplot() de matplotlib crea un boxplot a partir de los datos de la lista
    # La función title() establece el título del gráfico
    # La función ylabel() establece la etiqueta del eje y
    # La función grid() añade una cuadrícula al gráfico
    # La función show() muestra el gráfico
    # La función annotate() añade una anotación al gráfico   

    # Boxplot
    plt.figure(figsize=(6, 4))
    plt.boxplot(lista)
    plt.title("Diagrama de Caja (Boxplot)")
    plt.ylabel("Valor")
    plt.grid(True)
    plt.annotate(f'Mediana: {calcular_mediana(lista):.2f}', xy=(1, calcular_mediana(lista)), xytext=(1.1, calcular_mediana(lista) + 0.5),
                 arrowprops=dict(facecolor='black', arrowstyle='->'), fontsize=10, color='red')
    plt.show()

def create_scatter_plot(lista):
    # Scatter plot
    plt.figure(figsize=(10, 5))
    plt.plot(lista, marker='o', linestyle='-', alpha=0.7)
    plt.title("Secuencia de Números Aleatorios")
    plt.xlabel("Índice")
    plt.ylabel("Valor")
    plt.grid(True)
    plt.show()


def main():
    # Generar un diccionario de nombres y edades
    grades = get_grades()
    print("Diccionario de Nombres y Notas:")
    print(f"{'Nombre':<29} {'Nota':>0}")
    print("-" * 20)
    # Mostrar el diccionario de nombres y notas
    for name, grade in grades.items():
        print(f"{name:<10} {grade:>0}")
    
    print("-" * 20)
    # Calcular la media
    media = sum(grades.values()) / len(grades)
    print("Media:", media)
    print("-" * 20)
    # Calcular la mediana
    mediana = statistics.median(grades.values())
    print("Mediana:", mediana)
    print("-" * 20)
    # Calcular la desviación típica
    stdev = statistics.stdev(grades.values())
    print("Desviación Típica:", stdev)

    print("-" * 20)
    # Crear un histograma de las notas
    create_hist(grades.values())
    print("-" * 20)

    # Crear un histograma con la mediana   
    create_hist_with_median(grades.values())
    print("-" * 20) 
    # Crear un boxplot
    create_boxplot(grades.values())    
    print("-" * 20)
    # Crear un scatter plot
    create_scatter_plot(grades.values())
    print("-" * 20)

if __name__ == "__main__":
    import random
    import statistics
    main()
# Out:
# Diccionario de Nombres y Notas:
# Nombre                        Nota
# --------------------
# Nicolás    9.03
# Carlos     4.25
# Luis Gabriel 9.96
# Alfonso    7.94
# José Ignacio 5.91
# Emilio Eugenio 4.24
# Diana del Carmen 5.47
# Pablo      6.09
# Daniel     8.77
# Maria del Sol 4.67
# Jessica Ximena del Pilar 9.38
# Rodrigo    6.61
# Jorge      3.22
# Diana Fernanda 9.98
# Luis Fernando 2.24
# Javier     5.8
# Pedro      1.31
# Paloma     8.03
# Marcos     1.39
# Enrique    4.3
# Guiomar    5.25
# Daira      6.93
# Santiago   6.57
# Luis Enrique 5.67
# --------------------
# Media: 5.958749999999999
# --------------------
# Mediana: 5.855
# --------------------
# Desviación Típica: 2.5207612937364776
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
