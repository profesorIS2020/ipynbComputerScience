# %%
# Recordar y prácticar
# La función list(zip()) combina dos listas en una lista de tuplas

def get_list_one():
    lista_1 = 
    return 
def get_list_two():
    lista_2 = 
    return 
def main():
    lista_1 = 
    lista_2 = 
    
    print("Se han combinado dos listas en una lista de tuplas ", )

if __name__ == "__main__":
    main()
# Out:
# Se han combinado dos listas en una lista de tuplas  [('pedro', 5), ('juan', 7), ('sonia', 8), ('nicolás', 9)]

# %%
# Recordar y prácticar
# La función dict() convierte una lista de tuplas en un diccionario
def get_list_one():
    lista_1 = 
    return 
def get_list_two():
    lista_2 = 
    return 

def main():
    lista_1 = 
    lista_2 = 
    
    print("Se han combinado dos listas en una lista de tuplas ", lista)
    print("Se ha generado un dicionario con las listas anteriores ", dictionary_v1)
    print("Se ha generado un dicionario con las listas anteriores ", dictionary_v2)

if __name__ == "__main__":
    main()
# Out:
# Se han combinado dos listas en una lista de tuplas  [('pedro', 5), ('juan', 7), ('sonia', 8), ('nicolás', 9)]
# Se ha generado un dicionario con las listas anteriores  {'pedro': 5, 'juan': 7, 'sonia': 8, 'nicolás': 9}
# Se ha generado un dicionario con las listas anteriores  {'pedro': 5, 'juan': 7, 'sonia': 8, 'nicolás': 9}

# %%
# Recordar y prácticar:
# Listas 
"""Métodos de una lista:
1. append(x): Agrega un elemento al final de la lista.
2. extend(iterable): Agrega todos los elementos de iterable al final de la lista.   
3. insert(i, x): Inserta un elemento en la posición i de la lista.
4. remove(x): Elimina el primer elemento de la lista cuyo valor es igual a x.
5. pop([i]): Elimina el elemento en la posición i de la lista y lo retorna. Si no se especifica i,
   elimina y retorna el último elemento de la lista.
6. clear(): Elimina todos los elementos de la lista.
7. index(x[, start[, end]]): Retorna el índice del primer elemento cuyo valor es igual a x.
8. count(x): Retorna el número de veces que x aparece en la lista.
9. sort(key=None, reverse=False): Ordena los elementos de la lista en su lugar (los argumentos pueden ser
    usados para personalizar el orden de la lista).
10. reverse(): Invierte el orden de los elementos de la lista en su lugar.
11. copy(): Retorna una copia superficial de la lista.
"""
def add_element_end():
    return 
def insert_element():
    return 
def remove_element():
    return 
def delete_element():
    return 

def main():
    # Declarations
    lista = 
    animales = ['perro','gato','loro','gallina','toro','elefante','león','tigre']
    otros_animales = ['vaca','cebra','yegua','mono']
    
    # Add
    for item in otros_animales:
        lista = 
        print("Se han agregado a la lista los otros animales ", )
    
    for index , animal in enumerate(lista):
        if index ==  :
            n = 
            lista = 
            print("Se ha insertado un ornitorringo en la posición 5", lista)
    n = 'toro'
   
   # Delete
     = remove_element( , )
    print("Ha sido eliminado el toro ", )

    for index , animal in enumerate(lista):
        if index ==  :
            
            print("Ha sido eliminado el elemento de la posición 3, la gallina", lista)

if __name__ == "__main__":
    main()
# Out:
# Este es i vaca
# Esta es la nueva lista ['perro', 'gato', 'loro', 'gallina', 'toro', 'elefante', 'león', 'tigre', 'vaca']
# Este es i cebra
# Esta es la nueva lista ['perro', 'gato', 'loro', 'gallina', 'toro', 'elefante', 'león', 'tigre', 'vaca', 'cebra']
# Este es i yegua
# Esta es la nueva lista ['perro', 'gato', 'loro', 'gallina', 'toro', 'elefante', 'león', 'tigre', 'vaca', 'cebra', 'yegua']
# Este es i mono
# Esta es la nueva lista ['perro', 'gato', 'loro', 'gallina', 'toro', 'elefante', 'león', 'tigre', 'vaca', 'cebra', 'yegua', 'mono']
# Se ha insertado un ornitorringo en la posición 5 ['perro', 'gato', 'loro', 'gallina', 'toro', 'ornitorringo', 'elefante', 'león', 'tigre', 'vaca', 'cebra', 'yegua', 'mono']
# Ha sido eliminado el toro  ['perro', 'gato', 'loro', 'gallina', 'ornitorringo', 'elefante', 'león', 'tigre', 'vaca', 'cebra', 'yegua', 'mono']
# ...

# %%
# Recordar y prácticar:
# Diccionarios
"""
| Método                   | Descripción breve                              | Ejemplo                | Resultado / Acción                 |
| ------------------------ | ---------------------------------------------- | ---------------------- | ---------------------------------- |
| `get(clave, valor_def)`  | Obtiene el valor o el valor por defecto        | `d.get('x', 0)`        | `0` (si `'x'` no existe)           |
| `keys()`                 | Devuelve vista con las claves                  | `d.keys()`             | `dict_keys(['a', 'b'])`            |
| `values()`               | Devuelve vista con los valores                 | `d.values()`           | `dict_values([1, 2])`              |
| `items()`                | Devuelve vista de tuplas (clave, valor)        | `d.items()`            | `dict_items([('a', 1), ('b', 2)])` |
| `update(otro_dict)`      | Agrega o actualiza claves                      | `d.update({'c': 3})`   | `d` ahora contiene `'c': 3`        |
| `setdefault(clave, val)` | Si la clave no existe, la añade con ese valor  | `d.setdefault('d', 0)` | Añade `'d': 0` si no existía       |
| `pop(clave, val_def)`    | Elimina clave y devuelve su valor              | `d.pop('b')`           | `2` y elimina `'b'`                |
| `popitem()`              | Elimina y devuelve el último ítem              | `d.popitem()`          | `('c', 3)` (en orden de inserción) |
| `clear()`                | Elimina todos los elementos                    | `d.clear()`            | `d = {}`                           |
| `copy()`                 | Devuelve una copia superficial del diccionario | `d2 = d.copy()`        | `d2` es una copia independiente    |
| `'clave' in d`           | Verifica si la clave existe                    | `'a' in d`             | `True` o `False`                   |
"""
# add
def add_element():
    return 
def set_default():
    return 
# Get
def get_keys():
    return 
def get_values():
    return 
def get_items():
    return 
def get_value_from_key():
    return 
# Delete
def pop_element():
    return 
def pop_item():
    return 
def clear_element():
    return 
def copy_element():
    return 
# Check
def in_element():
    return 

def main():
    dictionary = {}
    animales = ['perro','gato','loro','gallina','toro','elefante','león','tigre']
    otros_animales = ['vaca','cebra','yegua','mono']
    
    # Agregar elementos a un diccionario
    for index, item in enumerate(animales):
        dictionary = 
        print("Este es el diccionario", dictionary)
    # Agregar un elemento con setdefault
    dictionary = set_default()
    # Obtener las claves
    keys = 
    print("Claves del diccionario", keys)
    print("Se ha agregado un ornitorringo en la posición 20", dictionary[20])
    # Obtener los valores
    values = 
    print("Valores del diccionario ", values)
    # Obtener los items de un diccionario
    items = 
    print("Miembros de un diccionario",items)

    # Obtener el elemento del diccionario con la clave 20
    key = 
    element = 
    print("Se ha obtenido el componente ", element)    

    # Borrar el elemento con la clave 20
    key = 
    dictionary = 
    print("Se ha eliminado el elemento con clave 20 ", dictionary)

    # Eliminar y retornar el último elemento
    item =
    print("Se ha eliminado el último elemento ", item)
    print("Este es el diccionario ahora ", dictionary)

if __name__ == "__main__":
    main()
# Out:
# Este es i perro
# Este es el diccionario {0: 'perro'}
# Este es i gato
# Este es el diccionario {0: 'perro', 1: 'gato'}
# Este es i loro
# Este es el diccionario {0: 'perro', 1: 'gato', 2: 'loro'}
# Este es i gallina
# Este es el diccionario {0: 'perro', 1: 'gato', 2: 'loro', 3: 'gallina'}
# Este es i toro
# Este es el diccionario {0: 'perro', 1: 'gato', 2: 'loro', 3: 'gallina', 4: 'toro'}
# Este es i elefante
# Este es el diccionario {0: 'perro', 1: 'gato', 2: 'loro', 3: 'gallina', 4: 'toro', 5: 'elefante'}
# Este es i león
# Este es el diccionario {0: 'perro', 1: 'gato', 2: 'loro', 3: 'gallina', 4: 'toro', 5: 'elefante', 6: 'león'}
# Este es i tigre
# Este es el diccionario {0: 'perro', 1: 'gato', 2: 'loro', 3: 'gallina', 4: 'toro', 5: 'elefante', 6: 'león', 7: 'tigre'}
# Claves del diccionario dict_keys([0, 1, 2, 3, 4, 5, 6, 7, 20])
# Se ha agregado un ornitorringo en la posición 20 ornitorringo
# ...
